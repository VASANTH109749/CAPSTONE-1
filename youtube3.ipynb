# %% [markdown]
# <a href="https://colab.research.google.com/github/VASANTH109749/CAPSTONE-1/blob/main/youtube3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 52.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
# ...

# %%
pip install pandas

# %%
import os
import json
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from pprint import pprint
api_key = 'AIzaSyCyerdo3WXvWBB6Ku5Sy1-YbhXymrnVtSA'
youtube = build("youtube", "v3", developerKey=api_key)
channel_ids = input("")
# "UC2J_VKrAzOEJuQvFFtj3KUw"
# Out:
# UC2J_VKrAzOEJuQvFFtj3KUw

# %% [markdown]
# **FETCHING CHANNEL DETAILS**

# %%
# def get_channel_details(channel_id):
#   request = youtube.channels().list(
#       part="snippet,statistics,contentDetails",
#       id=channel_id
#    )
#   response = request.execute()
#   z = dict(
#     channel_id = response["items"][0]["id"],
#     channel_name = response["items"][0]["snippet"]["title"],
#     channel_description = response["items"][0]["snippet"]["description"],
#     channel_views = response["items"][0]["statistics"]["viewCount"],
#     upload_id = response["items"][0]['contentDetails']['relatedPlaylists']['uploads'],
#     channel_status = response["items"][0]["snippet"]["publishedAt"])
#   return z

# %%
def get_channel_status(youtube, channel_ids):
    all_data=[]

    request=youtube.channels().list(
            part='snippet,contentDetails,statistics',
            id=channel_ids)

    response=request.execute()

    for i in range(len(response['items'])):
        data={
            'channel_name' : response['items'][i]['snippet']['title'],
            'channel_id':response['items'][i]['id'],
            'channel_video_count' :int( response['items'][i]['statistics']['videoCount']),
            'channel_description' : response['items'][i]['snippet']['description'],
            'upload_id' : response["items"][0]['contentDetails']['relatedPlaylists']['uploads'],
            'channel_playlist_id' : response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
            }
        all_data.append(data)

    return all_data

# %%
neh=get_channel_status(youtube,"UC2J_VKrAzOEJuQvFFtj3KUw")
print(neh)
# Out:
# [{'channel_name': 'Chennai Super Kings', 'channel_id': 'UC2J_VKrAzOEJuQvFFtj3KUw', 'channel_video_count': 1126, 'channel_description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove', 'upload_id': 'UU2J_VKrAzOEJuQvFFtj3KUw', 'channel_playlist_id': 'UU2J_VKrAzOEJuQvFFtj3KUw'}]

# %%
# ci=get_channel_details("UC2J_VKrAzOEJuQvFFtj3KUw")
# print(ci)

# %%
df = pd.DataFrame(neh)
print(df)
# Out:
#           channel_name                channel_id  channel_video_count  \
# 0  Chennai Super Kings  UC2J_VKrAzOEJuQvFFtj3KUw                 1126
#
#                                  channel_description  \
# 0  The Official YouTube Channel of the Chennai Su...
#
#                   upload_id       channel_playlist_id
# 0  UU2J_VKrAzOEJuQvFFtj3KUw  UU2J_VKrAzOEJuQvFFtj3KUw

# %%
data_frame = pd.DataFrame.from_dict(neh[0],orient="index").T

# %%
data_frame
# Out:
#           channel_name                channel_id channel_video_count  \
# 0  Chennai Super Kings  UC2J_VKrAzOEJuQvFFtj3KUw                1126
#
#                                  channel_description  \
# 0  The Official YouTube Channel of the Chennai Su...
#
#                   upload_id       channel_playlist_id
# 0  UU2J_VKrAzOEJuQvFFtj3KUw  UU2J_VKrAzOEJuQvFFtj3KUw

# %% [markdown]
# **FETCHING PLAYLIST DETAILS**

# %%
import os
from googleapiclient.discovery import build

# %%
def get_channel_playlists(channel_id):
    next_page = None
    playlists = []

    while True:
        request = youtube.playlists().list(
            part="snippet",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page
        )

        response = request.execute()
        playlists.extend(response.get('items', []))

        next_page = response.get('nextPageToken')
        if next_page is None:
            break

    playlist_details = []
    playlist_ID =[]
    for playlist in playlists:
        playlist_info = {
            "Playlist_ID": playlist["id"],
            "Channel_ID": channel_id,
            "Playlist_Title": playlist["snippet"]["title"],
            "Playlist_Description": playlist["snippet"]["description"],
            "PublishedAt": playlist["snippet"]["publishedAt"]
        }
        playlist_details.append(playlist_info)
        playlist_ID.append(playlist["id"])
    return playlist_details,playlist_ID

# %%
playlists = get_channel_playlists("UCk3JZr7eS3pg5AGEvBdEvFg")
print(playlists)
# Out:
# ([{'Playlist_ID': 'PL-NHxGqGGGk8VqgRI8w9vZhZDk1yJrMoY', 'Channel_ID': 'UCk3JZr7eS3pg5AGEvBdEvFg', 'Playlist_Title': 'Shorts', 'Playlist_Description': '', 'PublishedAt': '2023-01-06T13:49:32Z'}, {'Playlist_ID': 'PL-NHxGqGGGk9SpblNk8ziBlzPiAvU5Ux_', 'Channel_ID': 'UCk3JZr7eS3pg5AGEvBdEvFg', 'Playlist_Title': 'Chinese Food', 'Playlist_Description': '', 'PublishedAt': '2022-03-07T14:31:15Z'}, {'Playlist_ID': 'PL-NHxGqGGGk_lExzFmVgY7xwSem-241nU', 'Channel_ID': 'UCk3JZr7eS3pg5AGEvBdEvFg', 'Playlist_Title': 'Play Button Unboxing', 'Playlist_Description': '', 'PublishedAt': '2021-07-04T12:33:43Z'}, {'Playlist_ID': 'PL-NHxGqGGGk-LCfUGfScvoBXs_n4U1vlr', 'Channel_ID': 'UCk3JZr7eS3pg5AGEvBdEvFg', 'Playlist_Title': 'YouTube Award', 'Playlist_Description': '', 'PublishedAt': '2021-07-04T12:33:25Z'}, {'Playlist_ID': 'PL-NHxGqGGGk-DFlXSD_0YPn8a9kCAYi7q', 'Channel_ID': 'UCk3JZr7eS3pg5AGEvBdEvFg', 'Playlist_Title': 'Healthy Drinks', 'Playlist_Description': '', 'PublishedAt': '2021-03-05T14:10:02Z'}, {
# ...

# %%
import pandas as pd
pd.DataFrame(playlists)
# Out:
#                                                   0   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk8VqgRI8w9vZhZDk1y...
# 1                 PL-NHxGqGGGk8VqgRI8w9vZhZDk1yJrMoY
#
#                                                   1   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk9SpblNk8ziBlzPiAv...
# 1                 PL-NHxGqGGGk9SpblNk8ziBlzPiAvU5Ux_
#
#                                                   2   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk_lExzFmVgY7xwSem-...
# 1                 PL-NHxGqGGGk_lExzFmVgY7xwSem-241nU
#
#                                                   3   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk-LCfUGfScvoBXs_n4...
# 1                 PL-NHxGqGGGk-LCfUGfScvoBXs_n4U1vlr
#
#                                                   4   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk-DFlXSD_0YPn8a9kC...
# 1                 PL-NHxGqGGGk-DFlXSD_0YPn8a9kCAYi7q
#
#                                                   5   \
# 0  {'Playlist_ID': 'PL-NHxGqGGGk_UVNVJxLsv_j-PxKA...
# ...

# %%
def get_videoIds(youtube,playlist_id):
  video_ids = []
  nextPageToken = None
  while True:
    request = youtube.playlistItems().list(part="snippet,contentDetails",playlistId=playlist_id,maxResults=50,pageToken=nextPageToken)
    response =request.execute()
    for item in response['items']:
      video_ids.append(item['contentDetails']['videoId'])
    nextPageToken = response.get('nextPageToken')
    if not nextPageToken:
      break
  return video_ids

# %%
# v_id = get_videoIds(youtube,neh['upload_id'])

# %%
v_id = get_videoIds(youtube,data_frame['upload_id'][0])

# %%
v_id
# Out:
# ['YAbB6MTV-Sw',
#  'iBUYK18u7dI',
#  '_AzP2F64qiQ',
#  'j--OAtEOFPs',
#  'uIBy9dSPJXc',
#  'c-Elhx5OyH4',
#  '7yqd_b-cSHo',
#  'PNgsFF8daGY',
#  '8hbxvnj-02E',
#  '9LxOTWZawoU',
#  'KOGmZxI9jJw',
#  '98brRsgZ5cE',
#  '8CoILI6ThNc',
#  'b3-rS0baUrA',
#  '7CsqpL0R5J0',
#  'e4yOuMhD7xY',
#  'QaxBNasNL_s',
#  'AVNLIYL23go',
#  'xWx0KTT_lYI',
#  '5ksUpqdLHfc',
#  'WB4Ml8yjC2k',
#  'rXT9J3j0mPY',
#  '98W-G7hEPvY',
#  '2jU1xTBLBGs',
#  'lqjFpog8ZcA',
#  'KVhfaeC1LN4',
#  'w1tx7gH4-2w',
#  'fx8PhBgkiv8',
#  'baLQHOTWm3o',
#  'Erkjh_RM5y0',
#  'm_wYkpVaWCs',
#  'HYzJBwP40t0',
#  '6zv8mzeqZn0',
#  'IjsR8UBoUkE',
#  'f1gnaV4sWYo',
#  '85adJ60bQqk',
#  'zdZmopaH8vA',
#  'r88fWNdYmPc',
#  'o29L2ysDYeY',
#  'DntAi1keBkg',
#  'sWldDPznq60',
#  'R6v4PyiDOMI',
#  '51BFx3J2Ru4',
#  'xlripGf89Aw',
#  'Q4wsTEV8_XM',
#  'XZ0n5vOCj6U',
#  'W4P5AyK7Ues',
#  'RtD4q4LnLUw',
#  'WxbZtVJLID4',
#  '9OPmzW31nzk',
#  'MbzuFYeq4aU',
#  'fGHl5k_PyNE',
#  'g87iuCiFM0E',
#  '1QyC0VyxjUA',
#  'JNs4p0pk8Ms',
# ...

# %%
def get_video_details_by_id(video_id):
    video_details = []

    for i in video_id:
      # Fetch video information by video ID
      video_info1 = youtube.videos().list(
          part="snippet,statistics,contentDetails",
          id=i
      ).execute()

      if "items" in video_info1:
          video_info = video_info1["items"][0]
          video_details.append( {
              "Video_ID": i,
              "Video_Title": video_info["snippet"]["title"],
              "Video_Description": video_info["snippet"]["description"],
              "PublishedAt": video_info["snippet"]["publishedAt"],
              "Tags": video_info["snippet"].get("tags", []),
              "Duration": video_info["contentDetails"]["duration"],
              "Dimensions": video_info["contentDetails"]["dimension"],
              "Definition": video_info["contentDetails"]["definition"],
              "View_Count": video_info["statistics"]["viewCount"],
              "Like_Count": video_info["statistics"]["likeCount"],
              "Favorite_Count": video_info["statistics"]["favoriteCount"],
              "Comment_Count": video_info["statistics"]["commentCount"]
          })

    return video_details

# %%
v=get_video_details_by_id(v_id)

# %%
import pandas as pd
pd.DataFrame(v)
# Out:
#          Video_ID                                        Video_Title  \
# 0     YAbB6MTV-Sw  Proteas vs Men In Blue | INDvSA World Cup Prev...
# 1     iBUYK18u7dI  Albie Agrees! 🥳 Kohli Ko Bowling Do! 🙌Check ou...
# 2     _AzP2F64qiQ  Battle of the Blues| #INDvSL CWC 2023 Preview ...
# 3     j--OAtEOFPs  Watch it fully or it might go right over your ...
# 4     uIBy9dSPJXc  Watch Badri pick his favourites under a min! 🥳...
# ...           ...                                                ...
# 1121  7jLIsp6nxc8                        CSK Whistle Podu - 2011 New
# 1122  gExoAZDWy5I                            CSK Whistle Podu - 2010
# 1123  tOC2sRyr1Uw  CSK Whistle Podu fan video ( 60 sec TELEVISION...
# 1124  l3HyqIgrM9I                  Whistle Podu 4 Super Kings (full)
# 1125  cZNbDuibM5A                                       Whistle Podu
#
#                                       Video_Description           PublishedAt  \
# ...

# %%
# def comments_details(c,max_comments=50):
#   print(c)
#   comments = []
    try:
#   for i in c:
#       request = youtube.commentThreads().list(part='snippet,replies',videoId=i,maxResults=max_comments)
#       response = request.execute()
#       print(response)


#       y = dict(
#       comment_id = response["items"][0]["id"],
#       comment_text = response["items"][0]["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
#       comment_author = response["items"][0]["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
#       channel_published_date = response["items"][0]["snippet"]["topLevelComment"]["snippet"]["publishedAt"])
#       comments.append(y)
       except
#   return comments

# %%
#IF COMMENTS ARE DISABLED

except HttpError as e:
            if e.resp.status == 403 and 'commentsDisabled' in str(e):
                print(f"Comments are disabled for video ID: {video_id}")
            else:
                print(f"An error occurred for video ID: {video_id}, error: {str(e)}")

# %%
import datetime

# %%
def comment(v):
        comment_data = []
        for i in v:
            try:
                #next_page_token = None
                #while True:
                    request = youtube.commentThreads().list(part="snippet,replies",
                                                            videoId=i)
                    response=request.execute()
                    for cmt in response['items']:
                        data = {"Comment_id ": cmt['snippet']['topLevelComment']['id'],
                                    "Video_id" : i,
                                    "Comment_text": cmt['snippet']['topLevelComment']['snippet']['textDisplay'],
                                    "Comment_author" : cmt['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                    "Comment_posted_date" : cmt['snippet']['topLevelComment']['snippet']['publishedAt']}
                        comment_data.append(data)
                    #next_page_token = response.get('nextPageToken')
                    #if next_page_token is None:
                        #break
            except HttpError as e:
               if e.resp.status == 403 and 'commentsDisabled' in str(e):
                print(f"Comments are disabled for video ID: ")
               else:
                print(f"An error occurred for video ID: , error: {str(e)}")
        return comment_data

# %%
com=comment(v_id)
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Comments are disabled for video ID:

# %%
import pandas as pd
pd.DataFrame(com)
# Out:
#                       Comment_id      Video_id  \
# 0      UgxEZVeOLPx3FcBfMCp4AaABAg  YAbB6MTV-Sw
# 1      Ugy5Ia9S6wiXhuG8CDB4AaABAg  YAbB6MTV-Sw
# 2      UgzSlLgv9TkjT2-jH3N4AaABAg  YAbB6MTV-Sw
# 3      UgyxHt7ZwtoJ_v9WiU14AaABAg  YAbB6MTV-Sw
# 4      UgyrtF_AnBJxcIgWFdh4AaABAg  YAbB6MTV-Sw
# ...                           ...          ...
# 21982  Ugwbn3d0_MQUAUR9JvV4AaABAg  cZNbDuibM5A
# 21983  UgzBoEPivokZJtIztxJ4AaABAg  cZNbDuibM5A
# 21984  UgzdC6bkb_1pKAd7MNl4AaABAg  cZNbDuibM5A
# 21985  Ugx2Iy25vQ3m2UNuPDB4AaABAg  cZNbDuibM5A
# 21986  UgxPgl5iZKQ1ZLWhqZJ4AaABAg  cZNbDuibM5A
#
#                                             Comment_text    Comment_author  \
# 0      An exciting and insightful preview, featuring ...  DualShock Dreams
# 1      This loser badrinath had nothing to offer in h...       Abhay kumar
# 2      Csk legend albie morkel. 27 runs off 6 balls f...           doc gun
# 3                                         I love csk msd        Jp Jitu YT
# ...

# %% [markdown]
# **CREATING A MAIN FUNCTION**

# %%
channel_ids =input()
def main(channel_ids):
  c =get_channel_status(youtube,channel_ids)

  p,p_id = get_channel_playlists(channel_ids)
  v_id = get_videoIds(youtube,c[0]['upload_id'])
  v = get_video_details_by_id(v_id)
  comm = comment(v_id)
  d = {'channel_details':c,
       'playlist_details':p,
       'video_details':v,
       'comments_details':comm
  }
  return d
  # UC2J_VKrAzOEJuQvFFtj3KUw
# Out:
# UC2J_VKrAzOEJuQvFFtj3KUw

# %%
data = main(channel_ids)
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Comments are disabled for video ID:

# %%
p,p_id = get_channel_playlists(channel_ids)

# %%
print(p_id)
# Out:
# ['PL7GssaCNTMlkTSuQvSmc6QHhSG_3vBv3r', 'PL7GssaCNTMlljlbRj9I2y_Yuv71aMoHMn', 'PL7GssaCNTMlmMDJBkpdDn-CcjXFuq0rxI', 'PL7GssaCNTMlmyqaq_HjLIgyiIbSe9OmjQ', 'PL7GssaCNTMlltZdJFQ6ONWdmFILDPzomS', 'PL7GssaCNTMlnIpq7uDNVruyU__KmBP9Gy', 'PL7GssaCNTMlnNRqa12s7p51x6uI9yNiNO', 'PL7GssaCNTMlltI4ObEFO_KyzzCIlBuhVL', 'PL7GssaCNTMlkBJu0aMuMw1Oq409odv0q6', 'PL7GssaCNTMll3CZy_6H2RvNJ83o0NvLhn', 'PL7GssaCNTMlkZbFDiTvhcxmDBzR3RNYjU', 'PL7GssaCNTMlkPDzG_3_n4YYGHr48Y3jJa', 'PL7GssaCNTMlla9utBgjzg44-qtpE6IF4k', 'PL7GssaCNTMlkA1w-zWCeNe5CS_OY24esp', 'PL7GssaCNTMllUTj8cdOPZyxZ3f1fnx4qS', 'PL7GssaCNTMlmMho_iVGWCCvg8_00bcy95', 'PL7GssaCNTMlmzmd5KygjwC7Dmya11MaRc', 'PL7GssaCNTMlk64TPwWDpIfU_7wfYIQ_CY', 'PL7GssaCNTMlnFGn9inw_5wrbXSKGryctj', 'PL7GssaCNTMlnnF5y3MAgCTua9HlrZnhle', 'PL7GssaCNTMllbsBhk5n2mo-1CqH7ls-wG', 'PL7GssaCNTMll7PMPcuCN3ErR8JfejaHne', 'PL7GssaCNTMlk6HTrxzImX_bM_xvhdLpGI', 'PL7GssaCNTMlmdBzUZKWnUJGTE5KyYCeWL', 'PL7GssaCNTMlkvoAraB-KbsWAEvOGIB3S3', 'PL7GssaCNTMlkrtMv5D6W8qY84bM54M7cw', 'PL7GssaC
# ...

# %%
data.keys()
# Out:
# dict_keys(['channel_details', 'playlist_details', 'video_details', 'comments_details'])

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 28.2 MB/s eta 0:00:00
# ...

# %%
import pymongo

# %%
# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://VASANTH:1234@cluster0.emidtkq.mongodb.net/?retryWrites=true&w=majority"
# Establish a connection to MongoDB Atlas
client = pymongo.MongoClient(connection_string)

# Choose or create a database
db = client["youtube_data_harvesting"]
channel_collection = db["chennai_Super_Kings"]
d ={"Name":"VASANTH"}
channel_collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('65475a12a01e9589ac8158fc'), acknowledged=True)
